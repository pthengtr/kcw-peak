# %%
import sys
import os

# add project root to path
sys.path.append(os.path.abspath(".."))

# %%
import src.main

src.main.run()
# Out:
# Requesting client token...
#
# === PEAK TOKEN REQUEST ===
# URL        : http://peakengineapidev.azurewebsites.net/api/v1/clienttoken
# Timestamp  : 20260402125323
# Signature  : a3803054cc322a35686e5ebdd0b1d306df23cc4a
# ConnectId  : 'kiatchaiautopart2007_peakapi_uat'
# HTTP Status: 200
# PEAK resCode: 200
# PEAK resDesc: Token Authorized
# ✅ Client token acquired
# Client token acquired.
